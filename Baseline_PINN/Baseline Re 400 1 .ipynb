# %% [markdown]
# # Baseline PINN Re 400 Nc 10000

# %%
import os
import random
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.contour as contour
import pandas as pd
import scipy
import sklearn
import scipy.optimize as opt
import time
import pandas as pd

from tensorflow import keras
from pyDOE import lhs
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

seed = 1232 

os.environ["PYTHONHASHSEED"] = str(seed)
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"

random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

print("TensorFlow version:", tf.__version__)
print("GPUs available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.10.0
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Data Acquired from Ansys Fluent

# %%
U_ansys = pd.read_excel("../savedata 400/U_ansys Re 400.xlsx")

x_true = np.linspace(-0.5,0.5,252)
y_true = np.linspace(-0.5,0.5,252)
umag_true = np.array(U_ansys['magnitude'])/4
u_true = np.array(U_ansys['x-velocity'])/4

X_true,Y_true = np.meshgrid(x_true,y_true)
Umag_true = umag_true.reshape(X_true.shape)
U_true = u_true.reshape(X_true.shape)

# === Plot ===
plt.figure(figsize=(6,5))
plt.contourf(X_true, Y_true, Umag_true, levels=50, cmap="jet")
plt.colorbar(label="U prediction")
plt.xlabel("x")
plt.ylabel("y")
plt.title(f"Fluent U Re 100")
plt.show()
plt.show()

# %% [markdown]
# ## Validation Data

# %%
# create the data for validation
a,b = -0.5,0.5   #x lower and upper bound   
c,d = -0.5,0.5   #y lower and upper bound
shape = 1000 

#x data
x = np.linspace(a, b, shape, endpoint=False)
x = tf.Variable(x,dtype=tf.float32)
x = tf.reshape(x, ([tf.shape(x)[0],1]))

#y data
y = np.linspace(c, d, shape, endpoint=False)     
y = tf.Variable(y, dtype=tf.float32)
y = tf.reshape(y, (tf.shape(y)[0],1))

#create for testing after training
X,Y = np.meshgrid(x,y)
xy_test = np.hstack((X.flatten()[:,None],Y.flatten()[:,None]))

#set params
ub = 1
Re = 400

print(f'Reynolds Number: {Re}')
# Out:
# Reynolds Number: 400

# %% [markdown]
# ## Training Data

# %%
#set the colloc points
lower = xy_test[0]
upper = xy_test[-1]
xy_train = lower + (upper-lower)*lhs(2,10000) #insert this on input


"""Set the dirichlet"""
#set the dirichlet
U = np.zeros([shape,shape])
U[0,:] = ub
V = np.zeros([shape,shape])
P = np.zeros([shape,shape])

#top dirichlet x,y -> u,v,p
u_top_boundary = U[0,:][:,None]
v_top_boundary = V[0,:][:,None]
p_top_boundary = P[0,:][:,None]
#set the domain x,y
xy_up_top_boundary = np.hstack((X[-1][:,None], Y[-1][:,None]))

#create random form index dirichlet top
index_dirtop = np.random.choice(u_top_boundary.shape[0],200, replace=False)
u_top_boundary = u_top_boundary[index_dirtop,:]
v_top_boundary = v_top_boundary[index_dirtop,:]
p_top_boundary = p_top_boundary[index_dirtop,:]
xy_up_top_boundary = xy_up_top_boundary[index_dirtop,:] #insert this on input


#dirichlet bottom left right x,y -> u,v
u_bottom_boundary = U[-1][:,None]
v_bottom_boundary = V[-1][:,None]
xy_u_bottom_boundary = np.hstack((X[0].flatten()[:,None],Y[0].flatten()[:,None]))

u_right_boundary = U[:,-1][:,None][::-1]
v_right_boundary = V[:,-1][:,None][::-1]
xy_u_right_boundary = np.hstack((X[:,-1].flatten()[:,None],Y[:,-1].flatten()[:,None]))

u_left_boundary = U[:,0][:,None][::-1]
v_left_boundary = V[:,0][:,None][::-1]
xy_u_left_boundary = np.hstack((X[:,0].flatten()[:,None],Y[:,0].flatten()[:,None]))

#create random form index for bottom left right
u_brl_boundary = np.vstack((u_bottom_boundary,u_right_boundary,u_left_boundary))
v_brl_boundary = np.vstack((v_bottom_boundary,v_right_boundary,v_left_boundary))
index_dirbrl = np.random.choice(u_brl_boundary.shape[0],300, replace=False)

#set the domain x,y
xy_u_brl_boundary = np.vstack((xy_u_bottom_boundary,xy_u_right_boundary,xy_u_left_boundary))

u_brl_boundary = u_brl_boundary[index_dirbrl,:]
v_brl_boundary = v_brl_boundary[index_dirbrl,:]
xy_u_brl_boundary = xy_u_brl_boundary[index_dirbrl,:]   #insert this on input


"""Set the Neumann"""
#set for neumann dp = 0
dp = np.zeros([shape,shape])
dp_dx_left_boundary = dp[:,0][:,None]
dp_dx_right_boundary = dp[:,-1][:,None]
dp_dx_rl_boundary = np.vstack((dp_dx_right_boundary,dp_dx_left_boundary))
dp_dy_bottom_boundary = dp[-1][:,None]

#set the domain x,y
xy_dp_rl_boundary = np.vstack((xy_u_right_boundary,xy_u_left_boundary))
xy_dp_bottom_boundary = xy_u_bottom_boundary

#index left right
index_neu_rl = np.random.choice(dp_dx_rl_boundary.shape[0], 75, replace=False)
dp_dx_rl_boundary = dp_dx_rl_boundary[index_neu_rl,:]
xy_dp_rl_boundary = xy_dp_rl_boundary[index_neu_rl,:] #insert this on input

#index bottom
index_neubot = np.random.choice(dp_dy_bottom_boundary.shape[0], 25, replace=False)
dp_dy_bottom_boundary = dp_dy_bottom_boundary[index_neubot,:]
xy_dp_bottom_boundary = xy_dp_bottom_boundary[index_neubot,:] #insert this on input

"""Stacking input"""
xy_input = np.vstack((xy_train,xy_up_top_boundary,xy_u_brl_boundary,xy_dp_rl_boundary,xy_dp_bottom_boundary))
xy_input = tf.Variable(xy_input,dtype = tf.float32)

fig,ax = plt.subplots()

plt.plot(xy_train[:,0],xy_train[:,1], 'o', markersize = 1, label = f'PDE collocation = {xy_train.shape[0]}')
plt.plot(xy_up_top_boundary[:,0],xy_up_top_boundary[:,1], '*', markersize = 4, label = f'Dirichlet collocation Top= {xy_up_top_boundary.shape[0]}')
plt.plot(xy_u_brl_boundary[:,0],xy_u_brl_boundary[:,1], '*', markersize = 4, label = f'Dirichlet collocation BRL= {xy_u_brl_boundary.shape[0]}')
#plt.plot(xy_dp_rl_boundary[:,0],xy_dp_rl_boundary[:,1], '*', markersize = 4, label = f'Neumann collocation BRL= {xy_dp_rl_boundary.shape[0]}')
#plt.plot(xy_dp_bottom_boundary[:,0],xy_dp_bottom_boundary[:,1], '*', markersize = 4, label = f'Neumann collocation bottom= {xy_dp_bottom_boundary.shape[0]}')
#plt.plot(xy_dp_boundary[:,0],xy_dp_boundary[:,1], '*', color = 'black', markersize = 5, label = f'Neumann collocation = {dP_data_boundary.shape[0]}')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Collocation points')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.axis("square")          # ensures x and y units are equal
plt.xlim(-0.5,0.5)
plt.ylim(-0.5,0.5)

plt.show()

fig.savefig(f'../savedata {Re}/LHS points {Re}')

# %% [markdown]
# ## Physics Informed Neural Network

# %%
class Neural_Net(tf.keras.Model):

    def __init__(self, activations, x_input):
        
        self.inputs_vec = x_input

        super().__init__()

        self.Layer_1 = tf.keras.layers.Dense(25, activation=activations, trainable=True)
        self.Layer_2 = tf.keras.layers.Dense(25, activation=activations, trainable=True)
        self.Layer_3 = tf.keras.layers.Dense(25, activation=activations, trainable=True)
        self.Layer_4 = tf.keras.layers.Dense(25, activation=activations, trainable=True)
        self.Layer_5 = tf.keras.layers.Dense(25, activation=activations, trainable=True)
        self.Output = tf.keras.layers.Dense(3, activation=tf.keras.activations.linear)
    
    def call(self,inputs_vec):

        x = self.Layer_1(inputs_vec)
        x = self.Layer_2(x)
        x = self.Layer_3(x)
        x = self.Layer_4(x)
        x = self.Layer_5(x)

        return self.Output(x)
    
    def Autograd(self):

        x = self.inputs_vec[:,0:1]
        y = self.inputs_vec[:,1:2]

        with tf.GradientTape(persistent=True) as tape:

            tape.watch(x)
            tape.watch(y)

            with tf.GradientTape(persistent=True) as tape:
                
                tape.watch(x)
                tape.watch(y)

                # Rebuild inputs from watched tensors
                g = tf.concat([x, y], axis=1)

                preds = self.call(g)
                U_pred = preds[:,0:1]
                V_pred = preds[:,1:2]
                P_pred = preds[:,2:3]

                # Gradients wrt x and y
                dU_dx = tape.gradient(U_pred, x)
                dV_dx = tape.gradient(V_pred, x)
                dV_dy = tape.gradient(V_pred, y)
                dU_dy = tape.gradient(U_pred, y)
                dP_dx = tape.gradient(P_pred, x)
                dP_dy = tape.gradient(P_pred, y)

            dU_dxx = tape.gradient(dU_dx, x)
            dU_dxy = tape.gradient(dU_dx, y)
            dU_dyy = tape.gradient(dU_dy, y)
            dV_dxx = tape.gradient(dV_dx, x)
            dV_dxy = tape.gradient(dV_dx, y)
            dV_dyy = tape.gradient(dV_dy, y)
            dP_dxx = tape.gradient(dP_dx, x)
            dP_dxy = tape.gradient(dP_dx, y)
            dP_dyy = tape.gradient(dP_dy, y)

        return (U_pred,V_pred,P_pred,
                dU_dx, dU_dy, dV_dx, dV_dy, dP_dx, dP_dy, 
                dU_dxx, dU_dxy, dU_dyy, dV_dxx, dV_dxy, dV_dyy, dP_dxx, dP_dxy, dP_dyy)

    def Loss_function(self):

        (u, v, p,
         du_dx, du_dy, dv_dx, dv_dy, dp_dx, dp_dy,
         du_dxx, _, du_dyy, dv_dxx, _, dv_dyy, _, _, _) = self.Autograd()
    
        # === PDE Residuals ===
        r_cont = du_dx[0:10000] + dv_dy[0:10000]
    
        r_mom_u = (
            u[0:10000] * du_dx[0:10000] +
            v[0:10000] * du_dy[0:10000] +
            dp_dx[0:10000] -
            (1/Re) * (du_dxx[0:10000] + du_dyy[0:10000])
        )
    
        r_mom_v = (
            u[0:10000] * dv_dx[0:10000] +
            v[0:10000] * dv_dy[0:10000] +
            dp_dy[0:10000] -
            (1/Re) * (dv_dxx[0:10000] + dv_dyy[0:10000])
        )
    
        loss_pde = tf.reduce_mean(tf.square(r_cont)) \
                 + tf.reduce_mean(tf.square(r_mom_u)) \
                 + tf.reduce_mean(tf.square(r_mom_v))
    
        loss_bcu_top = tf.reduce_mean(tf.square(u[10000:10200] - u_top_boundary))
        loss_bcv_top = tf.reduce_mean(tf.square(v[10000:10200] - v_top_boundary))
    
        loss_bcu_brl = tf.reduce_mean(tf.square(u[10200:10500] - u_brl_boundary))
        loss_bcv_brl = tf.reduce_mean(tf.square(v[10200:10500] - v_brl_boundary))
    
        loss_dirichlet = loss_bcu_top + loss_bcv_top + loss_bcu_brl + loss_bcv_brl
    
        w_pde, w_dir = 1,1
        total_loss = w_pde * loss_pde + w_dir * loss_dirichlet
    
        print(f"[Loss] total={total_loss} | pde={loss_pde} | dir={loss_dirichlet}")

        return total_loss, loss_pde, loss_dirichlet

def train(model, epochs):

    lr_schedule = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
        boundaries=[1000,10000],
        values=[1e-2,1e-3,1e-4]
    )
    optimizer = tf.keras.optimizers.Adam(
        learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999, epsilon=1e-7
    )

    loss_history = {
        "total": [],
        "pde": [],
        "dirichlet": []
        }

    @tf.function
    def train_step():
        with tf.GradientTape() as tape:
            total_loss, loss_pde, loss_dir = model.Loss_function()
        gradients = tape.gradient(total_loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        
        return (tf.cast(total_loss, tf.float32),
                tf.cast(loss_pde, tf.float32),
                tf.cast(loss_dir, tf.float32),
                )

    for epoch in range(epochs):
        total_loss, loss_pde, loss_dir = train_step()

        loss_history["total"].append(float(total_loss))
        loss_history["pde"].append(float(loss_pde))
        loss_history["dirichlet"].append(float(loss_dir))

        if epoch % 100 == 0:
            print(f"Epoch {epoch:05d} | "
                  f"Total Loss = {total_loss:.5e}, "
                  f"PDE = {loss_pde:.3e}, "
                  f"Dir = {loss_dir:.3e}"
                  )

    return loss_history

def get_weights(model):
    variables = model.trainable_variables
    weights = np.concatenate([v.numpy().flatten() for v in variables])
    return weights

def set_weights(model, flat_weights):
    idx = 0
    for var in model.trainable_variables:
        shape = var.shape
        size = np.prod(shape)
        new_val = np.reshape(flat_weights[idx:idx+size], shape)
        var.assign(new_val)
        idx += size

def loss_and_grad(flat_weights, model):
   
    set_weights(model, flat_weights)

    with tf.GradientTape() as tape:
        total_loss, loss_pde, loss_dir = model.Loss_function()

    grads = tape.gradient(total_loss, model.trainable_variables)

    grads = [g if g is not None else tf.zeros_like(v)
             for g, v in zip(grads, model.trainable_variables)]

    grads_flat = np.concatenate([g.numpy().flatten() for g in grads])

    return float(total_loss.numpy()), grads_flat.astype(np.float64)

def train_lbfgs(model, maxiter=50000):
    init_params = get_weights(model)

    lbfgs_history = {
        "total": [],
        "pde": [],
        "dirichlet": []
    }

    def callback(w):
        set_weights(model, w)
        total_loss, loss_pde, loss_dir = model.Loss_function()

        # Convert to Python floats
        total_loss, loss_pde, loss_dir = map(float, 
            [total_loss.numpy(), loss_pde.numpy(), loss_dir.numpy()])

        lbfgs_history["total"].append(total_loss)
        lbfgs_history["pde"].append(loss_pde)
        lbfgs_history["dirichlet"].append(loss_dir)

        print(f"LBFGS iter {len(lbfgs_history['total'])} | "
              f"Total={total_loss:.4e}, "
              f"PDE={loss_pde:.3e}, "
              f"Dir={loss_dir:.3e}"
              )

    result = opt.minimize(fun=lambda w: loss_and_grad(w, model),
                          x0=init_params,
                          jac=True,
                          method='L-BFGS-B',
                          callback=callback,
                          options={'disp': None,
                                   'maxcor': 50,
                                   'ftol': 1e-12,
                                   'gtol': 1e-12,
                                   'maxfun': 50000,
                                   'maxiter': maxiter})

    set_weights(model, result.x)
    return result, lbfgs_history

def standardize_inputs(x_input):

    x_min = np.min(x_input, axis=0)
    x_max = np.max(x_input, axis=0)
    x_scaled = 2.0 * (x_input - x_min) / (x_max - x_min) - 1.0

    return x_scaled # keep min/max for inverse transform

start_time = time.time()
xy_input_stdized = standardize_inputs(xy_input)

model = Neural_Net(tf.nn.tanh,xy_input_stdized)
history = train(model, epochs=30000)

print("switch to lbfgs")

result, lbfgs_history = train_lbfgs(model, maxiter=50000)

print("Final L-BFGS-B loss:", result.fun)

elapsed = time.time() - start_time                
print('Training time: %.2f' % (elapsed))
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# [Loss] total=Tensor("add_12:0", shape=(), dtype=float32) | pde=Tensor("add_8:0", shape=(), dtype=float32) | dir=Tensor("add_11:0", shape=(), dtype=float32)
# [Loss] total=Tensor("add_12:0", shape=(), dtype=float32) | pde=Tensor("add_8:0", shape=(), dtype=float32) | dir=Tensor("add_11:0", shape=(), dtype=float32)
# Epoch 00000 | Total Loss = 1.00814e+00, PDE = 2.510e-01, Dir = 7.572e-01
# Epoch 00100 | Total Loss = 1.44997e-02, PDE = 5.534e-04, Dir = 1.395e-02
# Epoch 00200 | Total Loss = 1.26939e-02, PDE = 6.009e-04, Dir = 1.209e-02
# Epoch 00300 | Total Loss = 1.73146e-02, PDE = 3.446e-03, Dir = 1.387e-02
# Epoch 00400 | Total Loss = 9.41772e-03, PDE = 8.532e-04, Dir = 8.565e-03
# Epoch 00500 | Total Loss = 9.26910e-03, PDE = 7.725e-04, Dir = 8.497e-03
# Epoch 00600 | Total Loss = 7.78633e-03, PDE = 8.958e-04, Dir = 6.891e-03
# Epoch 00700 | Total Loss = 7.13878e-03, PDE = 8.561e-04, Dir = 6.283e-03
# Epoch 00800 | Total Loss = 6.39365e-03, PDE = 1.078e-03, Dir = 5.315e-03
# Epoch 00900 | Total Loss = 3.29878e-02, PDE = 9.739e-04, Dir = 3.201e-02
# Epoch 01000 | Total Loss = 9.51234e-03, PDE = 1.107e-03, Dir = 8.405e-03
# Epoch 01100 | Total Loss = 6.84016e-03, PDE = 8.735e-04, Dir = 5.967e-03
# Epoch 01200 | Total Loss = 6.36136e-03, PDE = 9.808e-04, Dir = 5.381e-03
# Epoch 01300 | Total Loss = 6.03973e-03, PDE = 1.072e-03, Dir = 4.968e-03
# Epoch 01400 | Total Loss = 5.80535e-03, PDE = 1.127e-03, Dir = 4.678e-03
# Epoch 01500 | Total Loss = 5.63325e-03, PDE = 1.161e-03, Dir = 4.472e-03
# Epoch 01600 | Total Loss = 5.50040e-03, PDE = 1.193e-03, Dir = 4.307e-03
# Epoch 01700 | Total Loss = 5.39274e-03, PDE = 1.200e-03, Dir = 4.192e-03
# Epoch 01800 | Total Loss = 5.29702e-03, PDE = 1.198e-03, Dir = 4.099e-03
# Epoch 01900 | Total Loss = 5.22153e-03, PDE = 1.198e-03, Dir = 4.024e-03
# Epoch 02000 | Total Loss = 5.15464e-03, PDE = 1.193e-03, Dir = 3.962e-03
# Epoch 02100 | Total Loss = 5.09479e-03, PDE = 1.184e-03, Dir = 3.910e-03
# Epoch 02200 | Total Loss = 5.05052e-03, PDE = 1.175e-03, Dir = 3.875e-03
# Epoch 02300 | Total Loss = 5.00134e-03, PDE = 1.167e-03, Dir = 3.834e-03
# Epoch 02400 | Total Loss = 4.96372e-03, PDE = 1.148e-03, Dir = 3.815e-03
# Epoch 02500 | Total Loss = 4.91959e-03, PDE = 1.136e-03, Dir = 3.784e-03
# Epoch 02600 | Total Loss = 4.88982e-03, PDE = 1.121e-03, Dir = 3.769e-03
# Epoch 02700 | Total Loss = 4.86499e-03, PDE = 1.097e-03, Dir = 3.768e-03
# Epoch 02800 | Total Loss = 4.84338e-03, PDE = 1.085e-03, Dir = 3.758e-03
# Epoch 02900 | Total Loss = 4.80629e-03, PDE = 1.072e-03, Dir = 3.734e-03
# Epoch 03000 | Total Loss = 4.78213e-03, PDE = 1.056e-03, Dir = 3.726e-03
# Epoch 03100 | Total Loss = 4.76145e-03, PDE = 1.042e-03, Dir = 3.719e-03
# Epoch 03200 | Total Loss = 4.75170e-03, PDE = 1.025e-03, Dir = 3.727e-03
# Epoch 03300 | Total Loss = 4.74157e-03, PDE = 1.028e-03, Dir = 3.713e-03
# Epoch 03400 | Total Loss = 4.69392e-03, PDE = 9.954e-04, Dir = 3.699e-03
# Epoch 03500 | Total Loss = 4.68455e-03, PDE = 9.916e-04, Dir = 3.693e-03
# Epoch 03600 | Total Loss = 4.65742e-03, PDE = 9.589e-04, Dir = 3.699e-03
# Epoch 03700 | Total Loss = 4.75202e-03, PDE = 9.386e-04, Dir = 3.813e-03
# Epoch 03800 | Total Loss = 4.62074e-03, PDE = 9.224e-04, Dir = 3.698e-03
# Epoch 03900 | Total Loss = 4.60151e-03, PDE = 9.057e-04, Dir = 3.696e-03
# Epoch 04000 | Total Loss = 4.58199e-03, PDE = 9.162e-04, Dir = 3.666e-03
# Epoch 04100 | Total Loss = 4.56980e-03, PDE = 8.930e-04, Dir = 3.677e-03
# Epoch 04200 | Total Loss = 4.58325e-03, PDE = 9.191e-04, Dir = 3.664e-03
# Epoch 04300 | Total Loss = 4.56392e-03, PDE = 9.101e-04, Dir = 3.654e-03
# Epoch 04400 | Total Loss = 4.54536e-03, PDE = 8.715e-04, Dir = 3.674e-03
# Epoch 04500 | Total Loss = 4.49648e-03, PDE = 9.181e-04, Dir = 3.578e-03
# Epoch 04600 | Total Loss = 4.46464e-03, PDE = 8.583e-04, Dir = 3.606e-03
# Epoch 04700 | Total Loss = 4.44726e-03, PDE = 8.837e-04, Dir = 3.564e-03
# Epoch 04800 | Total Loss = 4.44911e-03, PDE = 8.659e-04, Dir = 3.583e-03
# Epoch 04900 | Total Loss = 4.62447e-03, PDE = 9.476e-04, Dir = 3.677e-03
# Epoch 05000 | Total Loss = 4.37158e-03, PDE = 8.698e-04, Dir = 3.502e-03
# Epoch 05100 | Total Loss = 4.33942e-03, PDE = 8.636e-04, Dir = 3.476e-03
# Epoch 05200 | Total Loss = 4.29241e-03, PDE = 8.419e-04, Dir = 3.451e-03
# Epoch 05300 | Total Loss = 4.24176e-03, PDE = 8.630e-04, Dir = 3.379e-03
# Epoch 05400 | Total Loss = 4.18888e-03, PDE = 8.160e-04, Dir = 3.373e-03
# Epoch 05500 | Total Loss = 4.10762e-03, PDE = 7.675e-04, Dir = 3.340e-03
# Epoch 05600 | Total Loss = 4.07143e-03, PDE = 7.541e-04, Dir = 3.317e-03
# Epoch 05700 | Total Loss = 3.98654e-03, PDE = 7.678e-04, Dir = 3.219e-03
# Epoch 05800 | Total Loss = 3.88576e-03, PDE = 7.775e-04, Dir = 3.108e-03
# Epoch 05900 | Total Loss = 3.83808e-03, PDE = 7.514e-04, Dir = 3.087e-03
# Epoch 06000 | Total Loss = 3.80309e-03, PDE = 9.560e-04, Dir = 2.847e-03
# Epoch 06100 | Total Loss = 3.61373e-03, PDE = 7.848e-04, Dir = 2.829e-03
# Epoch 06200 | Total Loss = 3.53607e-03, PDE = 7.277e-04, Dir = 2.808e-03
# Epoch 06300 | Total Loss = 3.43752e-03, PDE = 7.482e-04, Dir = 2.689e-03
# Epoch 06400 | Total Loss = 3.56352e-03, PDE = 9.855e-04, Dir = 2.578e-03
# Epoch 06500 | Total Loss = 3.33160e-03, PDE = 7.741e-04, Dir = 2.558e-03
# Epoch 06600 | Total Loss = 3.23882e-03, PDE = 8.377e-04, Dir = 2.401e-03
# Epoch 06700 | Total Loss = 3.19084e-03, PDE = 7.560e-04, Dir = 2.435e-03
# Epoch 06800 | Total Loss = 3.15160e-03, PDE = 8.047e-04, Dir = 2.347e-03
# Epoch 06900 | Total Loss = 3.11329e-03, PDE = 7.983e-04, Dir = 2.315e-03
# Epoch 07000 | Total Loss = 3.12158e-03, PDE = 7.907e-04, Dir = 2.331e-03
# Epoch 07100 | Total Loss = 3.05514e-03, PDE = 8.095e-04, Dir = 2.246e-03
# Epoch 07200 | Total Loss = 3.24018e-03, PDE = 1.004e-03, Dir = 2.236e-03
# Epoch 07300 | Total Loss = 2.99986e-03, PDE = 8.476e-04, Dir = 2.152e-03
# Epoch 07400 | Total Loss = 2.98300e-03, PDE = 8.296e-04, Dir = 2.153e-03
# Epoch 07500 | Total Loss = 2.96070e-03, PDE = 7.911e-04, Dir = 2.170e-03
# Epoch 07600 | Total Loss = 2.93371e-03, PDE = 7.739e-04, Dir = 2.160e-03
# Epoch 07700 | Total Loss = 2.97191e-03, PDE = 8.255e-04, Dir = 2.146e-03
# Epoch 07800 | Total Loss = 2.89186e-03, PDE = 8.059e-04, Dir = 2.086e-03
# Epoch 07900 | Total Loss = 3.42285e-03, PDE = 7.221e-04, Dir = 2.701e-03
# Epoch 08000 | Total Loss = 2.87544e-03, PDE = 7.755e-04, Dir = 2.100e-03
# Epoch 08100 | Total Loss = 2.86700e-03, PDE = 7.412e-04, Dir = 2.126e-03
# Epoch 08200 | Total Loss = 2.91109e-03, PDE = 7.952e-04, Dir = 2.116e-03
# Epoch 08300 | Total Loss = 2.81978e-03, PDE = 8.071e-04, Dir = 2.013e-03
# Epoch 08400 | Total Loss = 2.79490e-03, PDE = 7.805e-04, Dir = 2.014e-03
# Epoch 08500 | Total Loss = 2.77546e-03, PDE = 8.353e-04, Dir = 1.940e-03
# Epoch 08600 | Total Loss = 2.78452e-03, PDE = 7.541e-04, Dir = 2.030e-03
# Epoch 08700 | Total Loss = 2.76669e-03, PDE = 7.846e-04, Dir = 1.982e-03
# Epoch 08800 | Total Loss = 2.74777e-03, PDE = 8.560e-04, Dir = 1.892e-03
# Epoch 08900 | Total Loss = 2.73352e-03, PDE = 7.855e-04, Dir = 1.948e-03
# Epoch 09000 | Total Loss = 2.71116e-03, PDE = 7.870e-04, Dir = 1.924e-03
# Epoch 09100 | Total Loss = 2.69329e-03, PDE = 7.998e-04, Dir = 1.894e-03
# Epoch 09200 | Total Loss = 2.69624e-03, PDE = 8.030e-04, Dir = 1.893e-03
# Epoch 09300 | Total Loss = 2.67013e-03, PDE = 7.716e-04, Dir = 1.899e-03
# Epoch 09400 | Total Loss = 2.66174e-03, PDE = 7.689e-04, Dir = 1.893e-03
# Epoch 09500 | Total Loss = 2.64552e-03, PDE = 7.720e-04, Dir = 1.874e-03
# Epoch 09600 | Total Loss = 2.75433e-03, PDE = 7.571e-04, Dir = 1.997e-03
# Epoch 09700 | Total Loss = 2.67999e-03, PDE = 7.581e-04, Dir = 1.922e-03
# Epoch 09800 | Total Loss = 2.63525e-03, PDE = 7.616e-04, Dir = 1.874e-03
# Epoch 09900 | Total Loss = 2.61144e-03, PDE = 7.801e-04, Dir = 1.831e-03
# Epoch 10000 | Total Loss = 2.59181e-03, PDE = 7.556e-04, Dir = 1.836e-03
# Epoch 10100 | Total Loss = 2.59215e-03, PDE = 7.502e-04, Dir = 1.842e-03
# Epoch 10200 | Total Loss = 2.59136e-03, PDE = 7.523e-04, Dir = 1.839e-03
# Epoch 10300 | Total Loss = 2.58661e-03, PDE = 7.500e-04, Dir = 1.837e-03
# Epoch 10400 | Total Loss = 2.58694e-03, PDE = 7.514e-04, Dir = 1.836e-03
# Epoch 10500 | Total Loss = 2.58321e-03, PDE = 7.500e-04, Dir = 1.833e-03
# Epoch 10600 | Total Loss = 2.58199e-03, PDE = 7.487e-04, Dir = 1.833e-03
# Epoch 10700 | Total Loss = 2.58225e-03, PDE = 7.501e-04, Dir = 1.832e-03
# Epoch 10800 | Total Loss = 2.58023e-03, PDE = 7.490e-04, Dir = 1.831e-03
# Epoch 10900 | Total Loss = 2.57778e-03, PDE = 7.472e-04, Dir = 1.831e-03
# Epoch 11000 | Total Loss = 2.57831e-03, PDE = 7.488e-04, Dir = 1.830e-03
# Epoch 11100 | Total Loss = 2.57512e-03, PDE = 7.464e-04, Dir = 1.829e-03
# Epoch 11200 | Total Loss = 2.57146e-03, PDE = 7.461e-04, Dir = 1.825e-03
# Epoch 11300 | Total Loss = 2.57092e-03, PDE = 7.462e-04, Dir = 1.825e-03
# Epoch 11400 | Total Loss = 2.57041e-03, PDE = 7.460e-04, Dir = 1.824e-03
# Epoch 11500 | Total Loss = 2.56746e-03, PDE = 7.452e-04, Dir = 1.822e-03
# Epoch 11600 | Total Loss = 2.56303e-03, PDE = 7.436e-04, Dir = 1.819e-03
# Epoch 11700 | Total Loss = 2.56117e-03, PDE = 7.432e-04, Dir = 1.818e-03
# Epoch 11800 | Total Loss = 2.56096e-03, PDE = 7.428e-04, Dir = 1.818e-03
# Epoch 11900 | Total Loss = 2.55595e-03, PDE = 7.395e-04, Dir = 1.816e-03
# Epoch 12000 | Total Loss = 2.55546e-03, PDE = 7.407e-04, Dir = 1.815e-03
# Epoch 12100 | Total Loss = 2.55241e-03, PDE = 7.342e-04, Dir = 1.818e-03
# Epoch 12200 | Total Loss = 2.54887e-03, PDE = 7.399e-04, Dir = 1.809e-03
# Epoch 12300 | Total Loss = 2.54610e-03, PDE = 7.410e-04, Dir = 1.805e-03
# Epoch 12400 | Total Loss = 2.54375e-03, PDE = 7.381e-04, Dir = 1.806e-03
# Epoch 12500 | Total Loss = 2.54238e-03, PDE = 7.421e-04, Dir = 1.800e-03
# Epoch 12600 | Total Loss = 2.53613e-03, PDE = 7.361e-04, Dir = 1.800e-03
# Epoch 12700 | Total Loss = 2.53219e-03, PDE = 7.333e-04, Dir = 1.799e-03
# Epoch 12800 | Total Loss = 2.52962e-03, PDE = 7.326e-04, Dir = 1.797e-03
# Epoch 12900 | Total Loss = 2.52684e-03, PDE = 7.276e-04, Dir = 1.799e-03
# Epoch 13000 | Total Loss = 2.51830e-03, PDE = 7.338e-04, Dir = 1.784e-03
# Epoch 13100 | Total Loss = 2.51813e-03, PDE = 7.311e-04, Dir = 1.787e-03
# Epoch 13200 | Total Loss = 2.51332e-03, PDE = 7.307e-04, Dir = 1.783e-03
# Epoch 13300 | Total Loss = 2.50881e-03, PDE = 7.285e-04, Dir = 1.780e-03
# Epoch 13400 | Total Loss = 2.50828e-03, PDE = 7.350e-04, Dir = 1.773e-03
# Epoch 13500 | Total Loss = 2.49776e-03, PDE = 7.206e-04, Dir = 1.777e-03
# Epoch 13600 | Total Loss = 2.49405e-03, PDE = 7.267e-04, Dir = 1.767e-03
# Epoch 13700 | Total Loss = 2.49293e-03, PDE = 7.291e-04, Dir = 1.764e-03
# Epoch 13800 | Total Loss = 2.48739e-03, PDE = 7.041e-04, Dir = 1.783e-03
# Epoch 13900 | Total Loss = 2.48066e-03, PDE = 7.256e-04, Dir = 1.755e-03
# Epoch 14000 | Total Loss = 2.47813e-03, PDE = 7.117e-04, Dir = 1.766e-03
# Epoch 14100 | Total Loss = 2.47658e-03, PDE = 7.194e-04, Dir = 1.757e-03
# Epoch 14200 | Total Loss = 2.46498e-03, PDE = 7.162e-04, Dir = 1.749e-03
# Epoch 14300 | Total Loss = 2.46024e-03, PDE = 7.157e-04, Dir = 1.745e-03
# Epoch 14400 | Total Loss = 2.45832e-03, PDE = 7.153e-04, Dir = 1.743e-03
# Epoch 14500 | Total Loss = 2.45099e-03, PDE = 7.149e-04, Dir = 1.736e-03
# Epoch 14600 | Total Loss = 2.44682e-03, PDE = 7.103e-04, Dir = 1.736e-03
# Epoch 14700 | Total Loss = 2.44480e-03, PDE = 7.012e-04, Dir = 1.744e-03
# Epoch 14800 | Total Loss = 2.43729e-03, PDE = 7.140e-04, Dir = 1.723e-03
# Epoch 14900 | Total Loss = 2.43543e-03, PDE = 7.054e-04, Dir = 1.730e-03
# Epoch 15000 | Total Loss = 2.43325e-03, PDE = 7.078e-04, Dir = 1.725e-03
# Epoch 15100 | Total Loss = 2.42294e-03, PDE = 7.050e-04, Dir = 1.718e-03
# Epoch 15200 | Total Loss = 2.41998e-03, PDE = 7.062e-04, Dir = 1.714e-03
# Epoch 15300 | Total Loss = 2.41252e-03, PDE = 7.073e-04, Dir = 1.705e-03
# Epoch 15400 | Total Loss = 2.41139e-03, PDE = 7.038e-04, Dir = 1.708e-03
# Epoch 15500 | Total Loss = 2.40520e-03, PDE = 7.212e-04, Dir = 1.684e-03
# Epoch 15600 | Total Loss = 2.39831e-03, PDE = 7.106e-04, Dir = 1.688e-03
# Epoch 15700 | Total Loss = 2.39262e-03, PDE = 6.992e-04, Dir = 1.693e-03
# Epoch 15800 | Total Loss = 2.39058e-03, PDE = 7.023e-04, Dir = 1.688e-03
# Epoch 15900 | Total Loss = 2.38308e-03, PDE = 6.969e-04, Dir = 1.686e-03
# Epoch 16000 | Total Loss = 2.37914e-03, PDE = 6.957e-04, Dir = 1.683e-03
# Epoch 16100 | Total Loss = 2.37677e-03, PDE = 7.019e-04, Dir = 1.675e-03
# Epoch 16200 | Total Loss = 2.36887e-03, PDE = 6.825e-04, Dir = 1.686e-03
# Epoch 16300 | Total Loss = 2.36286e-03, PDE = 6.942e-04, Dir = 1.669e-03
# Epoch 16400 | Total Loss = 2.38176e-03, PDE = 6.999e-04, Dir = 1.682e-03
# Epoch 16500 | Total Loss = 2.35509e-03, PDE = 6.908e-04, Dir = 1.664e-03
# Epoch 16600 | Total Loss = 2.35161e-03, PDE = 6.879e-04, Dir = 1.664e-03
# Epoch 16700 | Total Loss = 2.37164e-03, PDE = 7.040e-04, Dir = 1.668e-03
# Epoch 16800 | Total Loss = 2.34229e-03, PDE = 6.905e-04, Dir = 1.652e-03
# Epoch 16900 | Total Loss = 2.35600e-03, PDE = 6.992e-04, Dir = 1.657e-03
# Epoch 17000 | Total Loss = 2.33466e-03, PDE = 6.992e-04, Dir = 1.635e-03
# Epoch 17100 | Total Loss = 2.33395e-03, PDE = 6.849e-04, Dir = 1.649e-03
# Epoch 17200 | Total Loss = 2.32843e-03, PDE = 6.877e-04, Dir = 1.641e-03
# Epoch 17300 | Total Loss = 2.32680e-03, PDE = 6.853e-04, Dir = 1.642e-03
# Epoch 17400 | Total Loss = 2.31976e-03, PDE = 6.866e-04, Dir = 1.633e-03
# Epoch 17500 | Total Loss = 2.31511e-03, PDE = 6.819e-04, Dir = 1.633e-03
# Epoch 17600 | Total Loss = 2.31159e-03, PDE = 6.904e-04, Dir = 1.621e-03
# Epoch 17700 | Total Loss = 2.30758e-03, PDE = 6.860e-04, Dir = 1.622e-03
# Epoch 17800 | Total Loss = 2.30519e-03, PDE = 6.836e-04, Dir = 1.622e-03
# Epoch 17900 | Total Loss = 2.30143e-03, PDE = 6.952e-04, Dir = 1.606e-03
# Epoch 18000 | Total Loss = 2.30072e-03, PDE = 6.818e-04, Dir = 1.619e-03
# Epoch 18100 | Total Loss = 2.29296e-03, PDE = 6.911e-04, Dir = 1.602e-03
# Epoch 18200 | Total Loss = 2.28977e-03, PDE = 6.849e-04, Dir = 1.605e-03
# Epoch 18300 | Total Loss = 2.28690e-03, PDE = 6.927e-04, Dir = 1.594e-03
# Epoch 18400 | Total Loss = 2.28182e-03, PDE = 6.821e-04, Dir = 1.600e-03
# Epoch 18500 | Total Loss = 2.27579e-03, PDE = 6.825e-04, Dir = 1.593e-03
# Epoch 18600 | Total Loss = 2.26972e-03, PDE = 6.799e-04, Dir = 1.590e-03
# Epoch 18700 | Total Loss = 2.27553e-03, PDE = 6.761e-04, Dir = 1.599e-03
# Epoch 18800 | Total Loss = 2.26383e-03, PDE = 7.025e-04, Dir = 1.561e-03
# Epoch 18900 | Total Loss = 2.25987e-03, PDE = 6.798e-04, Dir = 1.580e-03
# Epoch 19000 | Total Loss = 2.26005e-03, PDE = 6.717e-04, Dir = 1.588e-03
# Epoch 19100 | Total Loss = 2.24991e-03, PDE = 6.753e-04, Dir = 1.575e-03
# Epoch 19200 | Total Loss = 2.24783e-03, PDE = 6.678e-04, Dir = 1.580e-03
# Epoch 19300 | Total Loss = 2.24358e-03, PDE = 6.704e-04, Dir = 1.573e-03
# Epoch 19400 | Total Loss = 2.23947e-03, PDE = 6.745e-04, Dir = 1.565e-03
# Epoch 19500 | Total Loss = 2.23757e-03, PDE = 6.764e-04, Dir = 1.561e-03
# Epoch 19600 | Total Loss = 2.23192e-03, PDE = 6.740e-04, Dir = 1.558e-03
# Epoch 19700 | Total Loss = 2.22949e-03, PDE = 6.815e-04, Dir = 1.548e-03
# Epoch 19800 | Total Loss = 2.22501e-03, PDE = 6.733e-04, Dir = 1.552e-03
# Epoch 19900 | Total Loss = 2.22755e-03, PDE = 6.679e-04, Dir = 1.560e-03
# Epoch 20000 | Total Loss = 2.21479e-03, PDE = 6.718e-04, Dir = 1.543e-03
# Epoch 20100 | Total Loss = 2.21130e-03, PDE = 6.730e-04, Dir = 1.538e-03
# Epoch 20200 | Total Loss = 2.20604e-03, PDE = 6.653e-04, Dir = 1.541e-03
# Epoch 20300 | Total Loss = 2.20158e-03, PDE = 6.627e-04, Dir = 1.539e-03
# Epoch 20400 | Total Loss = 2.20073e-03, PDE = 6.545e-04, Dir = 1.546e-03
# Epoch 20500 | Total Loss = 2.19537e-03, PDE = 6.500e-04, Dir = 1.545e-03
# Epoch 20600 | Total Loss = 2.19284e-03, PDE = 6.612e-04, Dir = 1.532e-03
# Epoch 20700 | Total Loss = 2.18426e-03, PDE = 6.720e-04, Dir = 1.512e-03
# Epoch 20800 | Total Loss = 2.18162e-03, PDE = 6.665e-04, Dir = 1.515e-03
# Epoch 20900 | Total Loss = 2.18143e-03, PDE = 6.667e-04, Dir = 1.515e-03
# Epoch 21000 | Total Loss = 2.17705e-03, PDE = 6.596e-04, Dir = 1.517e-03
# Epoch 21100 | Total Loss = 2.16977e-03, PDE = 6.643e-04, Dir = 1.506e-03
# Epoch 21200 | Total Loss = 2.16555e-03, PDE = 6.654e-04, Dir = 1.500e-03
# Epoch 21300 | Total Loss = 2.16326e-03, PDE = 6.632e-04, Dir = 1.500e-03
# Epoch 21400 | Total Loss = 2.15886e-03, PDE = 6.626e-04, Dir = 1.496e-03
# Epoch 21500 | Total Loss = 2.15663e-03, PDE = 6.550e-04, Dir = 1.502e-03
# Epoch 21600 | Total Loss = 2.15122e-03, PDE = 6.693e-04, Dir = 1.482e-03
# Epoch 21700 | Total Loss = 2.14752e-03, PDE = 6.562e-04, Dir = 1.491e-03
# Epoch 21800 | Total Loss = 2.14616e-03, PDE = 6.529e-04, Dir = 1.493e-03
# Epoch 21900 | Total Loss = 2.14102e-03, PDE = 6.631e-04, Dir = 1.478e-03
# Epoch 22000 | Total Loss = 2.13516e-03, PDE = 6.551e-04, Dir = 1.480e-03
# Epoch 22100 | Total Loss = 2.12904e-03, PDE = 6.601e-04, Dir = 1.469e-03
# Epoch 22200 | Total Loss = 2.12411e-03, PDE = 6.527e-04, Dir = 1.471e-03
# Epoch 22300 | Total Loss = 2.11858e-03, PDE = 6.576e-04, Dir = 1.461e-03
# Epoch 22400 | Total Loss = 2.11570e-03, PDE = 6.560e-04, Dir = 1.460e-03
# Epoch 22500 | Total Loss = 2.11014e-03, PDE = 6.539e-04, Dir = 1.456e-03
# Epoch 22600 | Total Loss = 2.10524e-03, PDE = 6.657e-04, Dir = 1.440e-03
# Epoch 22700 | Total Loss = 2.10275e-03, PDE = 6.454e-04, Dir = 1.457e-03
# Epoch 22800 | Total Loss = 2.09389e-03, PDE = 6.575e-04, Dir = 1.436e-03
# Epoch 22900 | Total Loss = 2.09090e-03, PDE = 6.560e-04, Dir = 1.435e-03
# Epoch 23000 | Total Loss = 2.09119e-03, PDE = 6.701e-04, Dir = 1.421e-03
# Epoch 23100 | Total Loss = 2.08380e-03, PDE = 6.524e-04, Dir = 1.431e-03
# Epoch 23200 | Total Loss = 2.08019e-03, PDE = 6.554e-04, Dir = 1.425e-03
# Epoch 23300 | Total Loss = 2.07704e-03, PDE = 6.503e-04, Dir = 1.427e-03
# Epoch 23400 | Total Loss = 2.07205e-03, PDE = 6.850e-04, Dir = 1.387e-03
# Epoch 23500 | Total Loss = 2.06929e-03, PDE = 6.661e-04, Dir = 1.403e-03
# Epoch 23600 | Total Loss = 2.06178e-03, PDE = 6.647e-04, Dir = 1.397e-03
# Epoch 23700 | Total Loss = 2.05895e-03, PDE = 6.525e-04, Dir = 1.406e-03
# Epoch 23800 | Total Loss = 2.05746e-03, PDE = 6.479e-04, Dir = 1.410e-03
# Epoch 23900 | Total Loss = 2.05416e-03, PDE = 6.645e-04, Dir = 1.390e-03
# Epoch 24000 | Total Loss = 2.04514e-03, PDE = 6.520e-04, Dir = 1.393e-03
# Epoch 24100 | Total Loss = 2.04365e-03, PDE = 6.483e-04, Dir = 1.395e-03
# Epoch 24200 | Total Loss = 2.03785e-03, PDE = 6.518e-04, Dir = 1.386e-03
# Epoch 24300 | Total Loss = 2.03498e-03, PDE = 6.468e-04, Dir = 1.388e-03
# Epoch 24400 | Total Loss = 2.02827e-03, PDE = 6.449e-04, Dir = 1.383e-03
# Epoch 24500 | Total Loss = 2.02792e-03, PDE = 6.383e-04, Dir = 1.390e-03
# Epoch 24600 | Total Loss = 2.04638e-03, PDE = 6.461e-04, Dir = 1.400e-03
# Epoch 24700 | Total Loss = 2.04393e-03, PDE = 6.416e-04, Dir = 1.402e-03
# Epoch 24800 | Total Loss = 2.02320e-03, PDE = 6.438e-04, Dir = 1.379e-03
# Epoch 24900 | Total Loss = 2.01167e-03, PDE = 6.508e-04, Dir = 1.361e-03
# Epoch 25000 | Total Loss = 2.01437e-03, PDE = 6.477e-04, Dir = 1.367e-03
# Epoch 25100 | Total Loss = 2.00991e-03, PDE = 6.436e-04, Dir = 1.366e-03
# Epoch 25200 | Total Loss = 2.00428e-03, PDE = 6.407e-04, Dir = 1.364e-03
# Epoch 25300 | Total Loss = 2.00048e-03, PDE = 6.396e-04, Dir = 1.361e-03
# Epoch 25400 | Total Loss = 1.99523e-03, PDE = 6.370e-04, Dir = 1.358e-03
# Epoch 25500 | Total Loss = 1.99556e-03, PDE = 6.447e-04, Dir = 1.351e-03
# Epoch 25600 | Total Loss = 1.99460e-03, PDE = 6.402e-04, Dir = 1.354e-03
# Epoch 25700 | Total Loss = 1.98630e-03, PDE = 6.420e-04, Dir = 1.344e-03
# Epoch 25800 | Total Loss = 1.98472e-03, PDE = 6.343e-04, Dir = 1.350e-03
# Epoch 25900 | Total Loss = 1.98491e-03, PDE = 6.423e-04, Dir = 1.343e-03
# Epoch 26000 | Total Loss = 1.97955e-03, PDE = 6.381e-04, Dir = 1.341e-03
# Epoch 26100 | Total Loss = 1.97509e-03, PDE = 6.441e-04, Dir = 1.331e-03
# Epoch 26200 | Total Loss = 1.97060e-03, PDE = 6.311e-04, Dir = 1.340e-03
# Epoch 26300 | Total Loss = 1.96858e-03, PDE = 6.278e-04, Dir = 1.341e-03
# Epoch 26400 | Total Loss = 1.96558e-03, PDE = 6.401e-04, Dir = 1.325e-03
# Epoch 26500 | Total Loss = 1.95951e-03, PDE = 6.400e-04, Dir = 1.319e-03
# Epoch 26600 | Total Loss = 1.95767e-03, PDE = 6.479e-04, Dir = 1.310e-03
# Epoch 26700 | Total Loss = 1.95342e-03, PDE = 6.297e-04, Dir = 1.324e-03
# Epoch 26800 | Total Loss = 1.95287e-03, PDE = 6.347e-04, Dir = 1.318e-03
# Epoch 26900 | Total Loss = 1.94968e-03, PDE = 6.237e-04, Dir = 1.326e-03
# Epoch 27000 | Total Loss = 1.94004e-03, PDE = 6.249e-04, Dir = 1.315e-03
# Epoch 27100 | Total Loss = 1.94494e-03, PDE = 6.302e-04, Dir = 1.315e-03
# Epoch 27200 | Total Loss = 1.93718e-03, PDE = 6.227e-04, Dir = 1.315e-03
# Epoch 27300 | Total Loss = 1.93827e-03, PDE = 6.295e-04, Dir = 1.309e-03
# Epoch 27400 | Total Loss = 1.93079e-03, PDE = 6.251e-04, Dir = 1.306e-03
# Epoch 27500 | Total Loss = 1.92816e-03, PDE = 6.223e-04, Dir = 1.306e-03
# Epoch 27600 | Total Loss = 1.92659e-03, PDE = 6.457e-04, Dir = 1.281e-03
# Epoch 27700 | Total Loss = 1.92627e-03, PDE = 6.059e-04, Dir = 1.320e-03
# Epoch 27800 | Total Loss = 1.91969e-03, PDE = 6.298e-04, Dir = 1.290e-03
# Epoch 27900 | Total Loss = 1.91934e-03, PDE = 6.334e-04, Dir = 1.286e-03
# Epoch 28000 | Total Loss = 1.91208e-03, PDE = 6.304e-04, Dir = 1.282e-03
# Epoch 28100 | Total Loss = 1.90891e-03, PDE = 6.207e-04, Dir = 1.288e-03
# Epoch 28200 | Total Loss = 1.91158e-03, PDE = 6.244e-04, Dir = 1.287e-03
# Epoch 28300 | Total Loss = 1.90999e-03, PDE = 6.244e-04, Dir = 1.286e-03
# Epoch 28400 | Total Loss = 1.90065e-03, PDE = 6.160e-04, Dir = 1.285e-03
# Epoch 28500 | Total Loss = 1.89646e-03, PDE = 6.184e-04, Dir = 1.278e-03
# Epoch 28600 | Total Loss = 1.89553e-03, PDE = 6.250e-04, Dir = 1.270e-03
# Epoch 28700 | Total Loss = 1.89167e-03, PDE = 6.224e-04, Dir = 1.269e-03
# Epoch 28800 | Total Loss = 1.88702e-03, PDE = 6.163e-04, Dir = 1.271e-03
# Epoch 28900 | Total Loss = 1.88463e-03, PDE = 6.131e-04, Dir = 1.272e-03
# Epoch 29000 | Total Loss = 1.88271e-03, PDE = 6.154e-04, Dir = 1.267e-03
# Epoch 29100 | Total Loss = 1.88274e-03, PDE = 6.113e-04, Dir = 1.271e-03
# Epoch 29200 | Total Loss = 1.87981e-03, PDE = 6.116e-04, Dir = 1.268e-03
# Epoch 29300 | Total Loss = 1.88069e-03, PDE = 6.110e-04, Dir = 1.270e-03
# Epoch 29400 | Total Loss = 1.87706e-03, PDE = 6.204e-04, Dir = 1.257e-03
# Epoch 29500 | Total Loss = 1.88343e-03, PDE = 6.365e-04, Dir = 1.247e-03
# Epoch 29600 | Total Loss = 1.87105e-03, PDE = 6.058e-04, Dir = 1.265e-03
# Epoch 29700 | Total Loss = 1.86360e-03, PDE = 6.104e-04, Dir = 1.253e-03
# Epoch 29800 | Total Loss = 1.87495e-03, PDE = 6.158e-04, Dir = 1.259e-03
# Epoch 29900 | Total Loss = 1.86392e-03, PDE = 6.056e-04, Dir = 1.258e-03
# switch to lbfgs
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# [Loss] total=0.0018616042798385024 | pde=0.0006087946239858866 | dir=0.0012528096558526158
# [Loss] total=2.071188449859619 | pde=0.0016074666054919362 | dir=2.0695810317993164
# [Loss] total=0.00889786146581173 | pde=0.0006320575485005975 | dir=0.008265803568065166
# [Loss] total=0.0018653047736734152 | pde=0.0006058644503355026 | dir=0.0012594403233379126
# [Loss] total=0.0018615834414958954 | pde=0.000608788279350847 | dir=0.0012527952203527093
# [Loss] total=0.0018613405991345644 | pde=0.0006087322835810483 | dir=0.0012526082573458552
# [Loss] total=0.0018613405991345644 | pde=0.0006087322835810483 | dir=0.0012526082573458552
# LBFGS iter 1 | Total=1.8613e-03, PDE=6.087e-04, Dir=1.253e-03
# [Loss] total=0.001866198144853115 | pde=0.0006056582788005471 | dir=0.001260539866052568
# [Loss] total=0.001861290424130857 | pde=0.0006086912471801043 | dir=0.0012525991769507527
# [Loss] total=0.001861289725638926 | pde=0.0006086904322728515 | dir=0.0012525992933660746
# [Loss] total=0.001865545753389597 | pde=0.0006057918071746826 | dir=0.0012597539462149143
# [Loss] total=0.0018612854182720184 | pde=0.0006086881621740758 | dir=0.0012525973143056035
# [Loss] total=0.001861285651102662 | pde=0.0006086886860430241 | dir=0.001252596965059638
# [Loss] total=0.0018612854182720184 | pde=0.0006086881621740758 | dir=0.0012525973143056035
# [Loss] total=0.0018612854182720184 | pde=0.0006086881621740758 | dir=0.0012525973143056035
# LBFGS iter 2 | Total=1.8613e-03, PDE=6.087e-04, Dir=1.253e-03
# [Loss] total=0.0018670689314603806 | pde=0.0006059295847080648 | dir=0.0012611392885446548
# [Loss] total=0.001861303811892867 | pde=0.0006087177898734808 | dir=0.0012525860220193863
# [Loss] total=0.0018612858839333057 | pde=0.0006086893263272941 | dir=0.0012525964993983507
# [Loss] total=0.0018612862331792712 | pde=0.0006086882203817368 | dir=0.0012525980127975345
# [Loss] total=0.0018612854182720184 | pde=0.0006086881621740758 | dir=0.0012525973143056035
# [Loss] total=0.0018612854182720184 | pde=0.0006086881621740758 | dir=0.0012525973143056035
# LBFGS iter 3 | Total=1.8613e-03, PDE=6.087e-04, Dir=1.253e-03
# Final L-BFGS-B loss: 0.0018612854182720184
# Training time: 567.52

# %%
a, b = -0.5,0.5   
c, d = -0.5,0.5   
shape = 252  

x = np.linspace(a, b, shape, endpoint=False)
y = np.linspace(c, d, shape, endpoint=False)
X, Y = np.meshgrid(x, y)

xy_testing = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))
xy_testing_stdized = standardize_inputs(xy_testing)

U_flat = model.call(xy_testing_stdized)[:, 0].numpy()
V_flat = model.call(xy_testing_stdized)[:, 1].numpy()

U_magnitude = np.sqrt(U_flat**2 + V_flat**2)

U_grid = U_flat.reshape(X.shape)
V_grid = V_flat.reshape(X.shape)
Umagnitude_grid = U_magnitude.reshape(X.shape)
e_local = np.abs(Umagnitude_grid - Umag_true) 
e_grid = e_local.reshape(X.shape) 

fig, ax = plt.subplots(2, 1, figsize=(10, 12))

c1 = ax[0].contourf(X, Y, Umagnitude_grid, levels=50, cmap="jet")

fig.colorbar(c1, ax=ax[0], label="U velocity")

ax[0].set_xlabel("x")
ax[0].set_ylabel("y")
ax[0].set_title(f"PINN Predicted U velocity, Re={Re}")
ax[0].set_aspect("equal")

c2 = ax[1].contourf(
    X, Y, e_grid,
    levels=50,
    cmap="inferno"
)

fig.colorbar(c2, ax=ax[1], label="Error e")

ax[1].set_xlabel("x")
ax[1].set_ylabel("y")
ax[1].set_title("Absolute Relative Error e")
ax[1].set_aspect("equal")

plt.tight_layout()
plt.show()

fig.savefig(f'../savedata {Re}/PINN pred Re {Re}')

e_norm = np.sqrt(np.sum((Umag_true - Umagnitude_grid)**2))/np.sqrt(np.sum(Umag_true**2))
print(e_norm)
# Out:
# 0.7864920906387525

# %%
fig, ax = plt.subplots(figsize=(9,5))

ax.plot(history['total'], label='Total loss')
ax.plot(history['pde'], label='PDE loss')
ax.plot(history['dirichlet'], label='Dirichlet loss')
#ax.plot(history['neumann'], label='Neumann loss')

ax.set_xlabel('iteration', fontsize=12)
ax.set_ylabel('loss', fontsize=10)
ax.set_title(f"Loss Curve {Re}", fontsize=10)

# Set y-axis to log scale
ax.set_yscale('log')

# Place legend
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,5))

ax.plot(lbfgs_history['total'], label='Total loss')
ax.plot(lbfgs_history['pde'], label='PDE loss')
ax.plot(lbfgs_history['dirichlet'], label='Dirichlet loss')
#ax.plot(history['neumann'], label='Neumann loss')

ax.set_xlabel('iteration', fontsize=12)
ax.set_ylabel('loss', fontsize=10)
ax.set_title(f"Loss Curve {Re}", fontsize=10)

# Set y-axis to log scale
ax.set_yscale('log')

# Place legend
ax.legend()

plt.show()
